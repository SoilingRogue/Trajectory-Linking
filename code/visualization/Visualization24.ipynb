# %%
import numpy as np
import pandas as pd
import glob

# %%
path =r'C:\Users\User\Desktop\Stanley\Testing\Data24'
labelfiles = glob.glob(path + "/*labels.txt")
preds = glob.glob(path + "/*predictions.txt")
probs = glob.glob(path + "/*probabilities1.txt")
print(len(labelfiles), len(preds), len(probs)) #Ensure all files are present
# Out:
# 307 307 307

# %%
def correct(df1, df2):
    count = 0.0
    size = len(df2)
    if (len(df1) != size):
        return -1
    for i in range(size):
        if df1.iloc[i, 0] == df2.iloc[i, 0]:
            count = count + 1

    return count / size

# %%
def sort_rank(df, labels):
    df = df.sort_values('Prob', ascending=False)
    indexArr = df.index.values
    idx = labels[labels["Label"] == 1].index
    if len(idx) == 0:
        return -1
    idx = idx[0]
    for i in range(len(indexArr)):
        if indexArr[i] == idx:
            return i

# %%
result = []

for file in labelfiles:
    temp = []
    string = file.replace(path, '')[1: 9]
#     print(string)
    predspath = path + "/" + string + "predictions.txt"
#     print(preds)
    probspath = path + "/" + string + "probabilities1.txt"
    
    ## Opening files ##
    labels = pd.read_csv(file, header=None, usecols=[0], sep=',')
    preds = pd.read_csv(predspath, header=None, sep=' ')
    probs = pd.read_csv(probspath, header=None, sep=' ')
    labels.columns = ['Label']
    probs.columns = ['Prob']
    
    ## Processing ##
    val = correct(labels, preds)
    rank = sort_rank(probs, labels)
    
    ## Adding to temp, then to result ##
    temp.append(string)
    temp.append(val)
    temp.append(rank)
    result.append(temp)

# %%
result
# Out:
# [['SHC0734E', 1.0, 0],
#  ['SHC0735C', 1.0, 0],
#  ['SHC0736A', 1.0, 0],
#  ['SHC0737Y', 1.0, 0],
#  ['SHC0738U', 1.0, 0],
#  ['SHC0739S', 1.0, 0],
#  ['SHC0740L', 1.0, 0],
#  ['SHC0741J', 1.0, 0],
#  ['SHC0742G', 1.0, 0],
#  ['SHC0743D', 1.0, 0],
#  ['SHC0744B', 1.0, 0],
#  ['SHC0745Z', 1.0, 0],
#  ['SHC0746X', 1.0, 0],
#  ['SHC0747T', 1.0, 0],
#  ['SHC0748R', 1.0, 0],
#  ['SHC0749M', 1.0, 0],
#  ['SHC0750H', 1.0, 0],
#  ['SHC0751E', 1.0, 0],
#  ['SHC0752C', 1.0, 0],
#  ['SHC0753A', 1.0, 0],
#  ['SHC0754Y', 1.0, 0],
#  ['SHC0755U', 1.0, 0],
#  ['SHC0756S', 1.0, 0],
#  ['SHC0757P', 1.0, 0],
#  ['SHC0758L', 1.0, 0],
#  ['SHC0759J', 1.0, 0],
#  ['SHC0760D', 1.0, 0],
#  ['SHC0761B', 1.0, 0],
#  ['SHC0762Z', 1.0, 0],
#  ['SHC0763X', 1.0, 0],
#  ['SHC0764T', 1.0, 0],
#  ['SHC0765R', 1.0, 0],
#  ['SHC0766M', 1.0, 0],
#  ['SHC0767K', 1.0, 0],
#  ['SHC0768H', 1.0, 0],
#  ['SHC0769E', 1.0, 0],
#  ['SHC0770A', 1.0, 0],
#  ['SHC0771Y', 1.0, 0],
#  ['SHC0772U', 1.0, 0],
#  ['SHC0773S', 1.0, 0],
#  ['SHC0774P', 1.0, 0],
#  ['SHC0775L', 1.0, 0],
#  ['SHC0776J', 1.0, 0],
#  ['SHC0777G', 1.0, 0],
#  ['SHC0778D', 1.0, 0],
#  ['SHC0779B', 1.0, 0],
#  ['SHC0780X', 1.0, 0],
#  ['SHC0781T', 1.0, 0],
#  ['SHC0782R', 1.0, 0],
#  ['SHC0783M', 1.0, 0],
#  ['SHC0784K', 1.0, 0],
#  ['SHC0785H', 1.0, 0],
#  ['SHC0786E', 1.0, 0],
#  ['SHC0787C', 1.0, 0],
#  ['SHC0788A', 1.0, 0],
#  ['SHC0789Y', 1.0, 0],
#  ['SHC0790S', 1.0, 0],
#  ['SHC0791P', 1.0, 0],
#  ['SHC0792L', 1.0, 0],
#  ['SHC0793J', 1.0, 0],
#  ['SHC0794G', 1.0, 0],
#  ['SHC0795D', 1.0, 0],
#  ['SHC0796B', 1.0, 0],
#  ['SHC0797Z', 1.0, 0],
#  ['SHC0798X', 1.0, 0],
#  ['SHC0799T', 1.0, 0],
#  ['SHC0800Y', 1.0, 0],
#  ['SHC0801U', 1.0, 0],
#  ['SHC0802S', 1.0, 0],
#  ['SHC0803P', 1.0, 0],
#  ['SHC0804L', 1.0, 0],
#  ['SHC0805J', 1.0, 0],
#  ['SHC0806G', 1.0, 0],
#  ['SHC0807D', 1.0, 0],
#  ['SHC0808B', 1.0, 0],
#  ['SHC0809Z', 1.0, 0],
#  ['SHC0810T', 1.0, 0],
#  ['SHC0811R', 1.0, 0],
#  ['SHC0812M', 1.0, 0],
#  ['SHC0813K', 1.0, 0],
#  ['SHC0814H', 1.0, 0],
#  ['SHC0816C', 1.0, 0],
#  ['SHC0817A', 1.0, 0],
#  ['SHC0818Y', 1.0, 0],
#  ['SHC0819U', 1.0, 0],
#  ['SHC0820P', 1.0, 0],
#  ['SHC0821L', 1.0, 0],
#  ['SHC0822J', 1.0, 0],
#  ['SHC0823G', 1.0, 0],
#  ['SHC0824D', 1.0, 0],
#  ['SHC0825B', 1.0, 0],
#  ['SHC0826Z', 1.0, 0],
#  ['SHC0827X', 1.0, 0],
#  ['SHC0828T', 1.0, 0],
#  ['SHC0829R', 1.0, 0],
#  ['SHC0830K', 1.0, 0],
#  ['SHC0831H', 1.0, 0],
#  ['SHC0832E', 1.0, 0],
#  ['SHC0833C', 1.0, 0],
#  ['SHC0834A', 1.0, 0],
#  ['SHC0835Y', 1.0, 0],
#  ['SHC0836U', 1.0, 0],
#  ['SHC0837S', 0.9992957746478873, 0],
#  ['SHC0838P', 1.0, 0],
#  ['SHC0839L', 1.0, 0],
#  ['SHC0840G', 1.0, 0],
#  ['SHC0841D', 1.0, 0],
#  ['SHC0842B', 1.0, 0],
#  ['SHC0843Z', 1.0, 0],
#  ['SHC0844X', 1.0, 0],
#  ['SHC0845T', 1.0, 0],
#  ['SHC0846R', 1.0, 0],
#  ['SHC0847M', 1.0, 0],
#  ['SHC0848K', 1.0, 0],
#  ['SHC0849H', 1.0, 0],
#  ['SHC0850C', 1.0, 0],
#  ['SHC0851A', 1.0, 0],
#  ['SHC0852Y', 1.0, 0],
#  ['SHC0853U', 1.0, 0],
#  ['SHC0854S', 1.0, 0],
#  ['SHC0855P', 1.0, 0],
#  ['SHC0856L', 1.0, 0],
#  ['SHC0857J', 1.0, 0],
#  ['SHC0858G', 1.0, 0],
#  ['SHC0859D', 1.0, 0],
#  ['SHC0860Z', 1.0, 0],
#  ['SHC0861X', 1.0, 0],
#  ['SHC0862T', 1.0, 0],
#  ['SHC0863R', 1.0, 0],
#  ['SHC0864M', 1.0, 0],
#  ['SHC0865K', 1.0, 0],
#  ['SHC0866H', 1.0, 0],
#  ['SHC0867E', 1.0, 0],
#  ['SHC0868C', 1.0, 0],
#  ['SHC0869A', 1.0, 0],
#  ['SHC0870U', 1.0, 0],
#  ['SHC0871S', 1.0, 0],
#  ['SHC0872P', 1.0, 0],
#  ['SHC0873L', 1.0, 0],
#  ['SHC0874J', 1.0, 0],
#  ['SHC0875G', 1.0, 0],
#  ['SHC0876D', 1.0, 0],
#  ['SHC0877B', 1.0, 0],
#  ['SHC0878Z', 1.0, 0],
#  ['SHC0879X', 1.0, 0],
#  ['SHC0880R', 1.0, 0],
#  ['SHC0881M', 1.0, 0],
#  ['SHC0882K', 1.0, 0],
#  ['SHC0883H', 1.0, 0],
#  ['SHC0884E', 1.0, 0],
#  ['SHC0885C', 1.0, 0],
#  ['SHC0886A', 1.0, 0],
#  ['SHC0887Y', 1.0, 0],
#  ['SHC0888U', 1.0, 0],
#  ['SHC0889S', 1.0, 0],
#  ['SHC0890L', 1.0, 0],
#  ['SHC0891J', 1.0, 0],
#  ['SHC0892G', 1.0, 0],
#  ['SHC0893D', 1.0, 0],
#  ['SHC0894B', 1.0, 0],
#  ['SHC0895Z', 1.0, 0],
#  ['SHC0896X', 1.0, 0],
#  ['SHC0897T', 1.0, 0],
#  ['SHC0898R', 1.0, 0],
#  ['SHC0899M', 1.0, 0],
#  ['SHC0900S', 1.0, 0],
#  ['SHC0901P', 1.0, 0],
#  ['SHC0904G', 1.0, 0],
#  ['SHC0905D', 1.0, 0],
#  ['SHC0906B', 1.0, 0],
#  ['SHC0907Z', 1.0, 0],
#  ['SHC0914C', 1.0, 0],
#  ['SHC0921G', 1.0, 0],
#  ['SHC0924Z', 1.0, 0],
#  ['SHC0926T', 1.0, 0],
#  ['SHC0934U', 1.0, 0],
#  ['SHC0936P', 1.0, 0],
#  ['SHC0939G', 1.0, 0],
#  ['SHC0941Z', 1.0, 0],
#  ['SHC0943T', 1.0, 0],
#  ['SHC0944R', 1.0, 0],
#  ['SHC0945M', 1.0, 0],
#  ['SHC0950Y', 1.0, 0],
#  ['SHC0951U', 1.0, 0],
#  ['SHC0953P', 1.0, 0],
#  ['SHC0954L', 1.0, 0],
#  ['SHC0955J', 1.0, 0],
#  ['SHC0959Z', 0.9992982456140351, 0],
#  ['SHC0964H', 1.0, 0],
#  ['SHC0969U', 1.0, 0],
#  ['SHC0974D', 1.0, 0],
#  ['SHC0978T', 1.0, 0],
#  ['SHC0979R', 1.0, 0],
#  ['SHC0981H', 1.0, 0],
#  ['SHC0984A', 1.0, 0],
#  ['SHC0989L', 1.0, 0],
#  ['SHC0993Z', 1.0, 0],
#  ['SHC0994X', 1.0, 0],
#  ['SHC0996R', 1.0, 0],
#  ['SHC0998K', 1.0, 0],
#  ['SHC0999H', 1.0, 0],
#  ['SHC1000H', 1.0, 0],
#  ['SHC1001E', 1.0, 0],
#  ['SHC1002C', 1.0, 0],
#  ['SHC1003A', 1.0, 0],
#  ['SHC1004Y', 1.0, 0],
#  ['SHC1005U', 1.0, 0],
#  ['SHC1006S', 1.0, 0],
#  ['SHC1007P', 1.0, 0],
#  ['SHC1008L', 1.0, 0],
#  ['SHC1009J', 1.0, 0],
#  ['SHC1010D', 1.0, 0],
#  ['SHC1011B', 1.0, 0],
#  ['SHC1012Z', 1.0, 0],
#  ['SHC1013X', 1.0, 0],
#  ['SHC1014T', 1.0, 0],
#  ['SHC1015R', 1.0, 0],
#  ['SHC1016M', 1.0, 0],
#  ['SHC1017K', 1.0, 0],
#  ['SHC1018H', 1.0, 0],
#  ['SHC1019E', 1.0, 0],
#  ['SHC1020A', 1.0, 0],
#  ['SHC1021Y', 1.0, 0],
#  ['SHC1022U', 1.0, 0],
#  ['SHC1023S', 1.0, 0],
#  ['SHC1024P', 1.0, 0],
#  ['SHC1025L', 1.0, 0],
#  ['SHC1026J', 1.0, 0],
#  ['SHC1027G', 1.0, 0],
#  ['SHC1028D', 1.0, 0],
#  ['SHC1029B', 1.0, 0],
#  ['SHC1030X', 1.0, 0],
#  ['SHC1031T', 1.0, 0],
#  ['SHC1032R', 1.0, 0],
#  ['SHC1033M', 0.9992967651195499, 0],
#  ['SHC1034K', 1.0, 0],
#  ['SHC1035H', 1.0, -1],
#  ['SHC1036E', 1.0, -1],
#  ['SHC1037C', 1.0, -1],
#  ['SHC1038A', 1.0, -1],
#  ['SHC1039Y', 1.0, -1],
#  ['SHC1040S', 1.0, -1],
#  ['SHC1041P', 1.0, -1],
#  ['SHC1042L', 1.0, -1],
#  ['SHC1043J', 1.0, -1],
#  ['SHC1044G', 1.0, -1],
#  ['SHC1045D', 1.0, -1],
#  ['SHC1046B', 1.0, -1],
#  ['SHC1047Z', 1.0, -1],
#  ['SHC1048X', 1.0, -1],
#  ['SHC1049T', 1.0, -1],
#  ['SHC1050M', 1.0, -1],
#  ['SHC1051K', 1.0, -1],
#  ['SHC1052H', 1.0, -1],
#  ['SHC1053E', 1.0, -1],
#  ['SHC1054C', 1.0, -1],
#  ['SHC1055A', 1.0, -1],
#  ['SHC1056Y', 1.0, -1],
#  ['SHC1057U', 0.9992977528089888, -1],
#  ['SHC1058S', 0.9992982456140351, -1],
#  ['SHC1059P', 1.0, -1],
#  ['SHC1060J', 1.0, -1],
#  ['SHC1061G', 0.9992982456140351, -1],
#  ['SHC1062D', 1.0, -1],
#  ['SHC1063B', 1.0, -1],
#  ['SHC1064Z', 1.0, -1],
#  ['SHC1065X', 1.0, -1],
#  ['SHC1066T', 1.0, -1],
#  ['SHC1067R', 1.0, -1],
#  ['SHC1068M', 1.0, -1],
#  ['SHC1069K', 1.0, -1],
#  ['SHC1070E', 1.0, -1],
#  ['SHC1071C', 1.0, -1],
#  ['SHC1072A', 1.0, -1],
#  ['SHC1073Y', 1.0, -1],
#  ['SHC1074U', 1.0, -1],
#  ['SHC1075S', 1.0, -1],
#  ['SHC1076P', 1.0, -1],
#  ['SHC1077L', 1.0, -1],
#  ['SHC1078J', 1.0, -1],
#  ['SHC1079G', 1.0, -1],
#  ['SHC1080B', 1.0, -1],
#  ['SHC1081Z', 1.0, -1],
#  ['SHC1082X', 1.0, -1],
#  ['SHC1083T', 1.0, -1],
#  ['SHC1084R', 1.0, -1],
#  ['SHC1085M', 1.0, -1],
#  ['SHC1086K', 1.0, -1],
#  ['SHC1087H', 1.0, -1],
#  ['SHC1088E', 1.0, -1],
#  ['SHC1089C', 1.0, -1],
#  ['SHC1090Y', 1.0, -1],
#  ['SHC1091U', 1.0, -1],
#  ['SHC1092S', 1.0, -1],
#  ['SHC1093P', 1.0, -1],
#  ['SHC1094L', 1.0, -1],
#  ['SHC1095J', 1.0, -1],
#  ['SHC1096G', 1.0, -1],
#  ['SHC1097D', 1.0, -1],
#  ['SHC1098B', 1.0, -1],
#  ['SHC1099Z', 1.0, -1],
#  ['SHC1100C', 0.9992977528089888, -1],
#  ['SHC1101A', 1.0, -1],
#  ['SHC1102Y', 1.0, -1],
#  ['SHC1103U', 1.0, -1],
#  ['SHC1104S', 1.0, -1],
#  ['SHC1105P', 1.0, -1]]
