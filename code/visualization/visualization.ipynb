# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df0 = pd.read_csv(r'C:\Users\User\Desktop\Stanley\data\datalabel0.txt', sep = ",", header = None)
df1 = pd.read_csv(r'C:\Users\User\Desktop\Stanley\data\datalabel1.txt', sep = ",", header = None)
df1
# Out:
#                0          1    2        3          4         5    6
# 0        1.29442  103.82194  0.0    926.0   3.248303  0.003508  1.0
# 1        1.29146  103.85959  0.0    660.0   4.202883  0.006368  0.0
# 2        1.37800  103.85801  1.0   6749.0   9.570765  0.001418  1.0
# 3        1.28365  103.84243  0.0   3751.0  10.575842  0.002819  1.0
# 4        1.28813  103.83592  0.0    300.0   0.877673  0.002926  0.0
# 5        1.35007  103.85809  1.0   1174.0   7.279868  0.006201  1.0
# 6        1.39263  103.89544  0.0   5426.0   6.278885  0.001157  1.0
# 7        1.39198  103.90935  0.0    360.0   1.549668  0.004305  0.0
# 8        1.36826  103.89557  1.0   1919.0   3.038260  0.001583  1.0
# 9        1.31000  103.79540  0.0   4321.0  12.875367  0.002980  1.0
# 10       1.29046  103.84495  0.0    780.0   5.922644  0.007593  0.0
# 11       1.38531  103.84714  1.0   2432.0  10.490859  0.004314  1.0
# 12       1.34247  103.98245  1.0   6847.0  15.785908  0.002306  0.0
# ...

# %%
header = ['Lat', 'Lon', 'Source', 'Timedif', 'Distdif', 'Speed', 'Flag']
df0.columns = header
df1.columns = header
print(df1.shape, df0.shape)
df1
# Out:
# (1778932, 7) (1778938, 7)
#              Lat        Lon  Source  Timedif    Distdif     Speed  Flag
# 0        1.29442  103.82194     0.0    926.0   3.248303  0.003508   1.0
# 1        1.29146  103.85959     0.0    660.0   4.202883  0.006368   0.0
# 2        1.37800  103.85801     1.0   6749.0   9.570765  0.001418   1.0
# 3        1.28365  103.84243     0.0   3751.0  10.575842  0.002819   1.0
# 4        1.28813  103.83592     0.0    300.0   0.877673  0.002926   0.0
# 5        1.35007  103.85809     1.0   1174.0   7.279868  0.006201   1.0
# 6        1.39263  103.89544     0.0   5426.0   6.278885  0.001157   1.0
# 7        1.39198  103.90935     0.0    360.0   1.549668  0.004305   0.0
# 8        1.36826  103.89557     1.0   1919.0   3.038260  0.001583   1.0
# 9        1.31000  103.79540     0.0   4321.0  12.875367  0.002980   1.0
# 10       1.29046  103.84495     0.0    780.0   5.922644  0.007593   0.0
# 11       1.38531  103.84714     1.0   2432.0  10.490859  0.004314   1.0
# ...

# %%
## Isolate quantile btw 0.25 and 0.75 ##

# q1 = df1[df1.apply(lambda x: x.between(x.quantile(.25), x.quantile(.75))).all(1)]
# q0 = df0.apply(df0["Speed"].between(df0["Speed"].quantile(.25), df0["Speed"].quantile(.75))).all(1)
# print(q1.shape, q0.shape) # (94982,) (87993,)
# print(q1)

speed1 = df1["Speed"]
s1q1 = speed1.quantile(.1)
s1q2 = speed1.quantile(.75)
# s1 = speed1[speed1.apply(speed1.between(s1q1, s1q2)).all(1)]
# s1q1 = np.quantile(s1, q=0.25, axis=0)
# s1q2 = np.quantile(s1, q=0.75, axis=0)

s0q1 = df0["Speed"].quantile(.1)
s0q2 = df0["Speed"].quantile(.75)
# s0q1 = np.quantile(s0, q=0.25, axis=0)
# s0q2 = np.quantile(s0, q=0.75, axis=0)

print(s1q1, s1q2, s0q1, s0q2)
# Out:
# 0.00027551594879324795 0.00437590591719874 0.0004836999159107547 0.005470459748330901

# %%
def isolate(arr, lower, upper):
    toDrop = []
    for i in range(len(arr)):
        if (arr[i] >= upper) or (arr[i] <= lower):
            toDrop.append(i)
    return toDrop

# %%
q1 = df1["Speed"].quantile(.9)
q0 = df0["Speed"].quantile(.9)
print(q1, q0)
# Out:
# 0.007237247828581293 0.012660862957017316

# %%
drop0 = isolate(df0["Speed"], s0q1, s0q2)
print(drop0)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(df1)
# Out:
#              Lat        Lon  Source  Timedif    Distdif     Speed  Flag
# 0        1.29442  103.82194     0.0    926.0   3.248303  0.003508   1.0
# 1        1.29146  103.85959     0.0    660.0   4.202883  0.006368   0.0
# 2        1.37800  103.85801     1.0   6749.0   9.570765  0.001418   1.0
# 3        1.28365  103.84243     0.0   3751.0  10.575842  0.002819   1.0
# 4        1.28813  103.83592     0.0    300.0   0.877673  0.002926   0.0
# 5        1.35007  103.85809     1.0   1174.0   7.279868  0.006201   1.0
# 6        1.39263  103.89544     0.0   5426.0   6.278885  0.001157   1.0
# 7        1.39198  103.90935     0.0    360.0   1.549668  0.004305   0.0
# 8        1.36826  103.89557     1.0   1919.0   3.038260  0.001583   1.0
# 9        1.31000  103.79540     0.0   4321.0  12.875367  0.002980   1.0
# 10       1.29046  103.84495     0.0    780.0   5.922644  0.007593   0.0
# 11       1.38531  103.84714     1.0   2432.0  10.490859  0.004314   1.0
# ...

# %%
df0.hist(bins=50, figsize=(40, 30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000008662748>,
# ...
#       dtype=object)

# %%
df1.hist(bins=50, figsize=(40, 30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000000092A5F28>,
# ...
#       dtype=object)

# %%
df0.plot(kind="scatter", x="Timedif", y="Speed", alpha=0.1)

# %%
df1.plot(kind="scatter", x="Timedif", y="Speed", alpha=0.1)

# %%
df0["Speed"].hist(range=(0, 0.01266), bins=200)

# %%
df1["Speed"].hist(range=(0, 0.007237), bins=200)

# %%
df1["Speed"].hist(range=(0, 0.0002), bins=200)

# %%
plt.scatter(df1["Timedif"], df1["Speed"], alpha=0.1)
plt.xlim(-10000, 300000)
plt.show()

# %%
df0.plot(kind="scatter", x="Timedif", y="Speed", alpha=0.1)

# %%
## 15 hrs ##
plt.scatter(df1["Timedif"], df1["Speed"], alpha=0.1)
plt.xlim(-1000, 54000)
# Out:
# (-1000, 54000)

# %%
plt.scatter(df0["Timedif"], df0["Speed"], alpha=0.1)
plt.xlim(-1000, 54000)
# Out:
# (-1000, 54000)

# %%
## 5 hrs ##
plt.scatter(df1["Timedif"], df1["Speed"], alpha=0.08)
plt.xlim(-500, 18000)
# Out:
# (-500, 18000)

# %%
plt.scatter(df0["Timedif"], df0["Speed"], alpha=0.08)
plt.xlim(-500, 18000)
# Out:
# (-500, 18000)

# %%
## 1 hr ##
plt.scatter(df1["Timedif"], df1["Speed"], alpha=0.08)
plt.xlim(-100, 3600)
# Out:
# (-100, 3600)

# %%
plt.scatter(df0["Timedif"], df0["Speed"], alpha=0.08)
plt.xlim(-100, 3600)
# Out:
# (-100, 3600)

# %%
## 10 mins ##
plt.scatter(df1["Timedif"], df1["Speed"], alpha=0.08)
plt.xlim(-100, 600)
plt.ylim(-0.01, 0.1)
# Out:
# (-0.01, 0.1)

# %%
plt.scatter(df0["Timedif"], df0["Speed"], alpha=0.08)
plt.xlim(-100, 600)
plt.ylim(-0.01, 0.1)
# Out:
# (-0.01, 0.1)

# %%
flag0 = pd.read_csv(r'C:\Users\User\Desktop\Stanley\flag0.txt', sep = ",", header = None)
flag1 = pd.read_csv(r'C:\Users\User\Desktop\Stanley\flag1.txt', sep = ",", header = None)
s0f0 = pd.read_csv(r'C:\Users\User\Desktop\Stanley\s0f0.txt', sep = ",", header = None)
s0f1 = pd.read_csv(r'C:\Users\User\Desktop\Stanley\s0f1.txt', sep = ",", header = None)
s1f0 = pd.read_csv(r'C:\Users\User\Desktop\Stanley\s1f0.txt', sep = ",", header = None)
s1f1 = pd.read_csv(r'C:\Users\User\Desktop\Stanley\s1f1.txt', sep = ",", header = None)

# %%
flag0.columns = header
flag1.columns = header
s0f0.columns = header
s0f1.columns = header
s1f0.columns = header
s1f1.columns = header
print(flag1.shape, s0f1.shape, s1f1.shape)
print(flag0.shape, s0f0.shape, s1f0.shape)
# Out:
# (2099586, 7) (910442, 7) (1189144, 7)
# (1458284, 7) (868496, 7) (589788, 7)

# %%
flag1.hist(bins=50, figsize=(40, 30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000029F98669198>,
# ...
#       dtype=object)

# %%
flag0.hist(bins=50, figsize=(40, 30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000029F98CD46D8>,
# ...
#       dtype=object)

# %%
## Flag 0 for both labels 0 and 1 ##
plt.scatter(flag0["Timedif"], flag0["Speed"], alpha=0.08)
plt.xlim(-100, 600)
plt.ylim(-0.01, 0.1)
# Out:
# (-0.01, 0.1)

# %%
## Flag 1 for both labels 0 and 1 ##
plt.scatter(flag1["Timedif"], flag1["Speed"], alpha=0.08)
plt.xlim(-100, 600)
plt.ylim(-0.01, 0.1)
# Out:
# (-0.01, 0.1)

# %%
## Flag 0 for label 0 ##
plt.scatter(s0f0["Timedif"], s0f0["Speed"], alpha=0.08)
plt.xlim(-100, 600)
plt.ylim(-0.01, 0.1)
# Out:
# (-0.01, 0.1)

# %%
## Flag 0 for label 1 ##
plt.scatter(s1f0["Timedif"], s1f0["Speed"], alpha=0.08)
plt.xlim(-100, 600)
plt.ylim(-0.01, 0.1)
# Out:
# (-0.01, 0.1)

# %%
## Flag 1 for label 0 ##
plt.scatter(s0f1["Timedif"], s0f1["Speed"], alpha=0.08)
plt.xlim(-100, 600)
plt.ylim(-0.01, 0.1)
# Out:
# (-0.01, 0.1)

# %%
## Flag 1 for label 1 ##
plt.scatter(s1f1["Timedif"], s1f1["Speed"], alpha=0.08)
plt.xlim(-100, 600)
plt.ylim(-0.01, 0.1)
# Out:
# (-0.01, 0.1)

# %%
## Flag 0 for label 0 ##
plt.scatter(s0f0["Timedif"], s0f0["Speed"], alpha=0.08)
plt.xlim(-100, 1000)
plt.ylim(-0.01, 0.1)
# Out:
# (-0.01, 0.1)

# %%
## Flag 0 for label 0 ##
plt.scatter(s0f0["Timedif"], s0f0["Speed"], alpha=0.08)
plt.xlim(1000, 1600)
plt.ylim(-0.01, 0.1)
# Out:
# (-0.01, 0.1)

# %%
## Flag 1 for label 1 ##
plt.scatter(s1f1["Timedif"], s1f1["Speed"], alpha=0.08)
plt.xlim(-100, 600)
plt.ylim(0.033, 5)
# Out:
# (0.033, 5)

# %%
s1f1["Speed"].quantile(0.99788)
# Out:
# 0.03332616682452727

# %%
s0f1["Speed"].quantile(0.925)
# Out:
# 0.0333700920894521

# %%
s0f0
# Out:
#             Lat        Lon  Source  Timedif    Distdif     Speed  Flag
# 0       1.31230  103.80396     1.0   3132.0   3.779294  0.001207   0.0
# 1       1.29146  103.85959     0.0    660.0   4.202883  0.006368   0.0
# 2       1.28796  103.82008     1.0   4926.0   1.142930  0.000232   0.0
# 3       1.28813  103.83592     0.0    300.0   0.877673  0.002926   0.0
# 4       1.39263  103.89544     0.0   6600.0  13.319019  0.002018   0.0
# 5       1.39198  103.90935     0.0    360.0   1.549668  0.004305   0.0
# 6       1.29046  103.84495     0.0    780.0   5.922644  0.007593   0.0
# 7       1.37367  103.93165     1.0   4675.0  10.745874  0.002299   0.0
# 8       1.28360  103.82870     1.0   5257.0  15.180925  0.002888   0.0
# 9       1.42983  103.83545     1.0   4614.0  16.186808  0.003508   0.0
# 10      1.31763  103.88728     0.0   1440.0   9.512628  0.006606   0.0
# 11      1.38336  103.90061     0.0  32640.0   7.417938  0.000227   0.0
# ...
